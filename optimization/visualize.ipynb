# %% [markdown]
# #Crystal Visualization
#
# Use this to view crystal json files outputted from the [optimization](https://github.com/patrickfuller/fomms-2015/tree/master/optimization) tutorial.
#
# To use, first install [imolecule](https://github.com/patrickfuller/imolecule) with `pip install imolecule`. Run the cell below, and then run the `view` function as needed.

# %%
import json
import numpy as np
import imolecule

def to_cartesian(fractional_crystal):
    """Converts fractional coordinates to cartesian."""
    uc = np.matrix(fractional_crystal["unitcell"])
    output = {"atoms": [], "unitcell": fractional_crystal["unitcell"]}
    for atom in fractional_crystal["atoms"]:
        cartesian = uc.dot(np.array(atom["location"]) - 0.5).tolist()[0]
        output["atoms"].append({"location": cartesian, "element": atom["element"], "label": atom["label"]})
    return output

def view(filename, draw_type="ball and stick"):
    """Converts fractional coordinates and renders with webGL."""
    with open(filename) as in_file:
        crystal = json.load(in_file)
    imolecule.draw(to_cartesian(crystal), format="json", drawing_type=draw_type)

# %%
view("Desktop/unpacked.json")
# Out:
# <div id="molecule_61781acf-335b-4672-907d-2d6548ff7e6a"></div>
#            <script type="text/javascript">
#            require.config({baseUrl: "/",
#                              paths: {imolecule: ['nbextensions/imolecule.min', 'https://rawgit.com/patrickfuller/imolecule/master/js/build/imolecule.min']}});
#            require(['imolecule'], function () {
#                var $d = $('#molecule_61781acf-335b-4672-907d-2d6548ff7e6a');
#                $d.width(400); $d.height(300);
#                $d.imolecule = jQuery.extend({}, imolecule);
#                $d.imolecule.create($d, {drawingType: 'ball and stick',
#                                         cameraType: 'perspective',
#                                         shader: 'toon'});
#                $d.imolecule.draw({"atoms":[{"element":"Si","label":"Si","location":[11.189605919999998,-9.400694880000003,-11.672857919999997]},{"element":"Al","label":"Al","location":[11.166510240000001,-11.651770560000003,-9.438852959999997]},{"element":"O","label":"O1","location":[9.7955808,12.546979199999997,-9.895996799999995]},{"element":"O","label":"O2","location":[12.5243856,12.479198399999996,-9.002294399999997]},{"element":"O","label":"O3","location":[11.685912,-10.669200000000004,-10.769615999999996]},{"element":"O","label":"O4","location":[10.8122928,-10.714387200000003,-8.048342399999996]},{"element":"Na","label":"Na","location":[-11.35956,-11.359560000000004,-11.359559999999997]},{"element":"Si","label":"Si","location":[11.189605919999998,3.1513051199999973,0.8791420800000046]},{"element":"Al","label":"Al","location":[11.166510240000001,0.9002294399999967,3.113147040000002]},{"element":"O","label":"O1","location":[9.7955808,-0.005020800000002787,2.6560032000000033]},{"element":"O","label":"O2","location":[12.5243856,-0.07280160000000369,3.549705600000003]},{"element":"O","label":"O3","location":[11.685912,1.8